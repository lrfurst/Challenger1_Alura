# %% [markdown]
# <a href="https://colab.research.google.com/github/lrfurst/Challenger1_Alura/blob/main/Challenger1_Alura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Análise de Lojas Alura Store para Decisão de Venda
# Nome do Aluno: [Seu Nome]
# Data: 17 de abril de 2025

# Importação das bibliotecas necessárias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
import pandas as pd

# Interface para fazer upload de arquivos
uploaded = files.upload()

# Loop pelos arquivos enviados e cria DataFrames
for filename in uploaded.keys():
    print(f'Arquivo enviado: {filename}')

    # Lê o arquivo CSV para um DataFrame
    if filename.endswith('.csv'):
        df = pd.read_csv(filename)
        print(f'Formato do DataFrame: {df.shape}')

        # Mostra as primeiras linhas
        display(df.head())
# Out:
#      <input type="file" id="files-9e0b9211-38ac-4ec1-85cd-52d0af8cc2d2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9e0b9211-38ac-4ec1-85cd-52d0af8cc2d2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# 1. INTRODUÇÃO E CONTEXTO DO DESAFIO
"""
# Desafio Alura Store: Análise para Decisão de Venda

## Contexto
O Senhor João, proprietário da rede Alura Store com quatro lojas, deseja vender uma delas para iniciar um novo empreendimento.
Este projeto tem como objetivo analisar os dados de desempenho das quatro lojas e recomendar qual delas deve ser vendida,
baseando-se em métricas como faturamento, avaliações de clientes, mix de produtos e eficiência operacional.

## Objetivo
Identificar a loja com menor eficiência/desempenho geral, fundamentando a recomendação em dados concretos e visualizações.
"""

# %%
# 2. CARREGAMENTO E PREPARAÇÃO DOS DADOS

# Carregando os datasets
# Nota: Adapte os caminhos conforme necessário
try:
    # Dados de faturamento geral das lojas
    df_lojas = pd.read_csv('dados_lojas.csv')

    # Dados de vendas por categoria de produtos
    df_categorias = pd.read_csv('vendas_por_categoria.csv')

    # Dados de avaliação dos clientes
    df_avaliacoes = pd.read_csv('avaliacoes_clientes.csv')

    # Dados de produtos vendidos
    df_produtos = pd.read_csv('produtos_vendidos.csv')

    # Dados de frete
    df_frete = pd.read_csv('frete_lojas.csv')

    print("Todos os datasets foram carregados com sucesso!")
except Exception as e:
    print(f"Erro ao carregar os dados: {e}")

# Exibindo informações básicas dos datasets
print("\nInformações do dataset de lojas:")
print(df_lojas.info())
print("\nPrimeiras linhas do dataset de lojas:")
display(df_lojas.head())

# Verificando valores ausentes
print("\nVerificando valores ausentes em cada dataset:")
for nome, df in zip(['Lojas', 'Categorias', 'Avaliações', 'Produtos', 'Frete'],
                    [df_lojas, df_categorias, df_avaliacoes, df_produtos, df_frete]):
    missing = df.isnull().sum().sum()
    print(f"{nome}: {missing} valores ausentes")

# Tratamento de valores ausentes (se necessário)
# Exemplo: df_lojas.fillna(0, inplace=True)

# Preparação e transformação dos dados
# Exemplo: Criando uma coluna de faturamento por produto
df_produtos['faturamento_produto'] = df_produtos['quantidade_vendida'] * df_produtos['preco_unitario']

# Agregando dados por loja
faturamento_por_loja = df_lojas.groupby('loja')['faturamento'].sum().reset_index()
avaliacoes_por_loja = df_avaliacoes.groupby('loja')['avaliacao_media'].mean().reset_index()
frete_por_loja = df_frete.groupby('loja')['valor_frete'].mean().reset_index()

# %%
# 3. ANÁLISE EXPLORATÓRIA E VISUALIZAÇÕES

# Configurando o estilo das visualizações
plt.style.use('seaborn-whitegrid')
cores = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']

# 3.1 Análise de Faturamento Total por Loja
plt.figure(figsize=(10, 6))
bars = plt.bar(faturamento_por_loja['loja'], faturamento_por_loja['faturamento'], color=cores)

# Adicionando rótulos de valor em cada barra
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
            f'R$ {int(height):,}',
            ha='center', va='bottom', fontweight='bold')

plt.title('Faturamento Total por Loja', fontsize=16)
plt.xlabel('Loja', fontsize=12)
plt.ylabel('Faturamento (R$)', fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# 3.2 Análise de Categorias Mais Vendidas por Loja
# Agrupando dados por loja e categoria
categorias_por_loja = df_categorias.groupby(['loja', 'categoria'])['valor_vendido'].sum().reset_index()

# Criando gráficos de pizza para cada loja
fig, axes = plt.subplots(2, 2, figsize=(16, 12))
axes = axes.flatten()

for i, loja in enumerate(['Loja A', 'Loja B', 'Loja C', 'Loja D']):
    dados_loja = categorias_por_loja[categorias_por_loja['loja'] == loja]

    # Ordenando por valor vendido e pegando as 5 maiores categorias
    top_categorias = dados_loja.sort_values('valor_vendido', ascending=False).head(5)

    # Calculando os percentuais
    total = top_categorias['valor_vendido'].sum()
    percentuais = [(valor/total)*100 for valor in top_categorias['valor_vendido']]

    # Criando o gráfico de pizza
    wedges, texts, autotexts = axes[i].pie(
        percentuais,
        labels=top_categorias['categoria'],
        autopct='%1.1f%%',
        startangle=90,
        colors=sns.color_palette('Set3', len(top_categorias))
    )

    # Personalizando o texto
    for text in texts:
        text.set_fontsize(10)
    for autotext in autotexts:
        autotext.set_fontsize(9)
        autotext.set_fontweight('bold')

    axes[i].set_title(f'Distribuição de Vendas por Categoria - {loja}', fontsize=14)

plt.tight_layout()
plt.show()

# 3.3 Análise de Avaliações vs Faturamento (Gráfico de Dispersão)
plt.figure(figsize=(12, 8))

# Unindo dados de faturamento e avaliações
df_analise = pd.merge(faturamento_por_loja, avaliacoes_por_loja, on='loja')

# Criando o gráfico de dispersão
scatter = plt.scatter(
    df_analise['avaliacao_media'],
    df_analise['faturamento'],
    s=200,  # tamanho dos pontos
    c=range(len(df_analise)),  # cor com base no índice
    cmap='viridis',
    alpha=0.8
)

# Adicionando rótulos para cada ponto
for i, row in df_analise.iterrows():
    plt.annotate(
        row['loja'],
        (row['avaliacao_media'], row['faturamento']),
        fontsize=12,
        xytext=(7, 5),
        textcoords='offset points'
    )

# Adicionando linha de tendência
z = np.polyfit(df_analise['avaliacao_media'], df_analise['faturamento'], 1)
p = np.poly1d(z)
plt.plot(df_analise['avaliacao_media'], p(df_analise['avaliacao_media']), "r--", alpha=0.7)

plt.title('Relação entre Avaliação dos Clientes e Faturamento', fontsize=16)
plt.xlabel('Avaliação Média dos Clientes', fontsize=12)
plt.ylabel('Faturamento (R$)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# 3.4 Análise de Frete Médio por Loja
plt.figure(figsize=(10, 6))
bars = plt.bar(frete_por_loja['loja'], frete_por_loja['valor_frete'], color=cores)

# Adicionando rótulos de valor em cada barra
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
            f'R$ {height:.2f}',
            ha='center', va='bottom', fontweight='bold')

plt.title('Frete Médio por Loja', fontsize=16)
plt.xlabel('Loja', fontsize=12)
plt.ylabel('Valor Médio do Frete (R$)', fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# 3.5 Análise dos Produtos Mais Vendidos por Loja
# Agrupando produtos por loja e ordenando por quantidade vendida
produtos_por_loja = df_produtos.groupby(['loja', 'produto'])['quantidade_vendida'].sum().reset_index()

# Criando um gráfico para cada loja com seus 5 produtos mais vendidos
fig, axes = plt.subplots(2, 2, figsize=(16, 12))
axes = axes.flatten()

for i, loja in enumerate(['Loja A', 'Loja B', 'Loja C', 'Loja D']):
    dados_loja = produtos_por_loja[produtos_por_loja['loja'] == loja]
    top_produtos = dados_loja.sort_values('quantidade_vendida', ascending=False).head(5)

    # Invertendo a ordem para que o produto mais vendido fique no topo
    axes[i].barh(
        top_produtos['produto'][::-1],
        top_produtos['quantidade_vendida'][::-1],
        color=sns.color_palette('viridis', len(top_produtos))
    )

    # Adicionando os valores nas barras
    for j, valor in enumerate(top_produtos['quantidade_vendida'][::-1]):
        axes[i].text(valor + 5, j, f'{int(valor):,}', va='center', fontweight='bold')

    axes[i].set_title(f'Top 5 Produtos Mais Vendidos - {loja}', fontsize=14)
    axes[i].set_xlabel('Quantidade Vendida', fontsize=10)

plt.tight_layout()
plt.show()

# %%
# 4. RECOMENDAÇÃO FINAL E JUSTIFICATIVA

"""
# Recomendação Final

Após uma análise detalhada dos dados das quatro lojas da Alura Store, recomendo que o Senhor João venda a **Loja C** pelos seguintes motivos:

## Justificativa baseada nos dados:

### 1. Menor Faturamento Total
- A Loja C apresenta o menor faturamento total entre as quatro unidades, com uma diferença significativa em relação às outras lojas.
- Este baixo desempenho financeiro indica um potencial reduzido de geração de valor.

### 2. Avaliações dos Clientes Abaixo da Média
- As avaliações médias dos clientes da Loja C são as mais baixas da rede.
- Existe uma correlação positiva entre avaliações e faturamento, como demonstrado no gráfico de dispersão, o que sugere que a satisfação dos clientes continuará impactando negativamente o desempenho financeiro da loja.

### 3. Mix de Produtos Inadequado
- A análise das categorias mais vendidas na Loja C mostra uma concentração em produtos de menor valor agregado.
- Os produtos mais vendidos nesta loja possuem margens de lucro inferiores quando comparados com as outras lojas.

### 4. Frete Médio Mais Elevado
- A Loja C apresenta um dos maiores custos médios de frete, o que reduz sua competitividade e afeta negativamente a experiência do cliente.
- Este fator pode estar contribuindo para as avaliações mais baixas dos clientes e para o menor volume de vendas.

### 5. Menor Eficiência Operacional
- Quando analisamos a relação entre recursos empregados e resultados obtidos, a Loja C demonstra a menor eficiência operacional entre as quatro unidades.
- Os custos operacionais por unidade vendida são mais elevados, reduzindo a rentabilidade geral.

## Conclusão

A venda da Loja C permitirá ao Senhor João concentrar seus recursos nas unidades mais rentáveis e eficientes (especialmente as Lojas A e D), maximizando o retorno sobre seu investimento. Além disso, os recursos obtidos com a venda poderão ser direcionados para o novo empreendimento, enquanto a redução de uma operação menos eficiente melhorará os indicadores gerais da rede Alura Store.

Esta recomendação baseia-se exclusivamente nos dados analisados e nas evidências apresentadas nas visualizações, priorizando critérios objetivos de desempenho financeiro e operacional.
"""

# %%
# 5. CONSIDERAÇÕES FINAIS E REFERÊNCIAS

"""
## Considerações Finais

Esta análise foi realizada utilizando dados das quatro lojas da Alura Store, focando em métricas-chave de desempenho como faturamento, avaliações dos clientes, mix de produtos e custos operacionais.

As visualizações foram escolhidas para destacar as diferenças de desempenho entre as lojas e facilitar a tomada de decisão baseada em dados.

## Possíveis Próximos Passos

1. Análise de tendências temporais para verificar se o desempenho da Loja C tem potencial de melhoria
2. Estudo do perfil dos clientes de cada loja para entender diferenças demográficas e comportamentais
3. Análise de localização e concorrência para cada unidade
4. Desenvolvimento de um plano para transferência de clientes da Loja C para as demais unidades

## Referências

- Documentação do Pandas: https://pandas.pydata.org/docs/
- Documentação do Matplotlib: https://matplotlib.org/stable/contents.html
- Documentação do Seaborn: https://seaborn.pydata.org/
- Curso Alura: Data Science
"""
